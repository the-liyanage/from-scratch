# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def f(x):
    return 3*x**2 - 4*x +5

# %%
f(3.0)
# Out:
# 20.0

# %%
xs = np.arange(-5, 5, 0.25)
print(xs)
ys = f(xs)
plt.plot(xs, ys)
plt.show()
# Out:
# [-5.   -4.75 -4.5  -4.25 -4.   -3.75 -3.5  -3.25 -3.   -2.75 -2.5  -2.25
#  -2.   -1.75 -1.5  -1.25 -1.   -0.75 -0.5  -0.25  0.    0.25  0.5   0.75
#   1.    1.25  1.5   1.75  2.    2.25  2.5   2.75  3.    3.25  3.5   3.75
#   4.    4.25  4.5   4.75]

# %%
# Making it bit complex

# Input features
a = 3.0
b = -6.0
c = 20.00

d = a*b + c
print(f"Initial value of d: {d}")
# Out:
# Initial value of d: 2.0

# %%
h = 0.0001
# Input features
a = 3.0
b = -6.0
c = 20.00
d = a*b + c

b += h
d1 = a*b +c

print("d", d)
print(f"d1, {d1:.4f}")
print(f"Slope: {(d1 - d)/h}")
# Out:
# d 2.0
# d1, 2.0003
# Slope: 2.9999999999930083
