# %%
import os
os.getcwd()
# Out:
# '/Users/hiruniliyanage/Documents/ml-from-scratch/regression/basic-linear-regression'

# %%
# !kaggle --version
# Out:
# Kaggle API 1.7.4.5

# %%
import os
os.listdir(os.path.expanduser("~/.kaggle"))
# Out:
# ['kaggle.json']

# %%
# !kaggle datasets list | head
# Out:
# ref                                                  title                                           size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ---------------------------------------------------  ----------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# neurocipher/heartdisease                             Heart Disease                                   3491  2025-12-11 15:29:14.327000           2114        194  1.0
# ahmeduzaki/wind-and-solar-energy-production-dataset  Wind & Solar Energy Production Dataset        395372  2026-01-02 21:06:22.780000              0         33  1.0
# kundanbedmutha/exam-score-prediction-dataset         Exam Score Prediction Dataset                 325454  2025-11-28 07:29:01.047000           5863        243  1.0
# guriya79/heart-failure-prediction-dataset            Heart Failure Clinical Records Study            4067  2025-12-27 05:13:37.790000              0         28  1.0
# neurocipher/student-performance                      Student Performance                            49705  2025-12-12 12:06:28.973000           1261        117  1.0
# ishank2005/salary-csv                                Salary.csv                                       392  2025-12-29 15:48:58.240000              0         26  1.0
# dansbecker/melbourne-housing-snapshot                Melbourne Housing Snapshot                    461423  2018-06-05 12:52:24.087000         200095       1722  0.7058824
# datasnaek/youtube-new                                Trending YouTube Video Statistics          210575746  2019-06-03 00:56:47.177000         292850       5843  0.7941176

# %%
# !mkdir -p data

# %%
os.listdir("data")

os.getcwd()
# Out:
# '/Users/hiruniliyanage/Documents/ml-from-scratch/regression/basic-linear-regression'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading the dataset to pandas 

salary_data = pd.read_csv('data/Salary_Data.csv.xls')
salary_data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
salary_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
plt.scatter(salary_data['YearsExperience'],melb_data['Salary'])
plt.xlabel('years of experince')
plt.ylabel('salary')
# Out:
# Text(0, 0.5, 'salary')

# %%
#Define the feature (independent variable) and the target (dependent variable)

#X must be 2D even if we have one feature
X = salary_data.iloc[:,0:1]
y = salary_data.iloc[:,-1]

# %%
#Split the data into training and testing sets (80% train, 20% test)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=2)

print(f"Training set size: {X_train.shape[0]}")
print(f"Testing set size: {X_test.shape[0]}")
# Out:
# Training set size: 24
# Testing set size: 6

# %%
from sklearn.linear_model import LinearRegression
model =LinearRegression()

# %%
#Train the model on the training data 

model.fit(X_train, y_train)



#Print the intercept and the coefficient
print(f"Intercept: {model.intercept_}")
print(f"Coefficient: {model.coef_}")
# Out:
# Intercept: 24393.16915194835
# Coefficient: [9569.58688543]

# %%
#Predict the Salaries for the rest of the set

y_pred =

# %%
from sklearn.metrics import mean_squared_error, r1_score
from sklearn.datasets import
